# %%
import os
import requests
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
import ollama

# %%
message = "Tell me something about transformer technology"
response = ollama.chat(model='llama3.2', messages=[{"role": "user", "content": message}])
print(response['message']['content'])
# Out:
# Transformer technology is a crucial component in the field of electrical engineering, and it has revolutionized the way we transmit and distribute electricity. Here's an overview:
#
# **What is a Transformer?**
#
# A transformer is an electrical device that transfers electrical energy from one circuit to another through electromagnetic induction. It consists of two coils of wire, known as primary and secondary coils, which are connected to a common magnetic core.
#
# **How Does it Work?**
#
# The transformer works on the principle of electromagnetic induction, where a changing magnetic field induces a voltage in the secondary coil. When an alternating current (AC) flows through the primary coil, it generates a magnetic field that induces a voltage in the secondary coil.
#
# **Key Functions of a Transformer:**
#
# 1. **Voltage Transformation**: Transformers can step up or step down voltages, making it possible to transmit power over long distances with reduced energy loss.
# 2. **Isolation**: Transformers provide electrical isolation between the primary and secondary circuits, preventing electrical shock and ensuring safety.
# 3. **Power Transmission**: Transformers enable efficient transmission of power from a high-voltage source to a low-voltage load.
#
# **Types of Transformers:**
#
# 1. **Step-Up Transformer**: Increases voltage from the primary coil to the secondary coil.
# 2. **Step-Down Transformer**: Decreases voltage from the primary coil to the secondary coil.
# 3. **Autotransformer**: A type of transformer that uses only one coil and provides both step-up and step-down capabilities.
#
# **Applications of Transformers:**
#
# 1. **Power Grids**: Transformers are used extensively in power grids to transmit and distribute electricity over long distances.
# 2. **Industrial Power Systems**: Transformers are used in industrial power systems, such as those found in factories, warehouses, and data centers.
# 3. **Home Appliances**: Many home appliances, such as refrigerators and air conditioners, use transformers to regulate voltage.
#
# **Modern Transformer Technology:**
#
# 1. **High-Voltage Transformers**: Advances in materials science and manufacturing have led to the development of high-voltage transformers with improved efficiency and reliability.
# 2. **Digital Transformers**: Some modern transformers use digital signal processing techniques to optimize their performance and reduce energy losses.
# 3. **Wind-Solar Power Systems**: Transformers play a crucial role in wind-solar power systems, which generate electricity from renewable sources.
#
# In summary, transformer technology has revolutionized the way we transmit and distribute electricity, enabling efficient and safe transmission of power over long distances.

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        for irrelevant in soup.body(["script", "style", "img", "input", "link"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
web = Website("https://pl.wikipedia.org/wiki/Du%C5%BCy_model_j%C4%99zykowy")
print("Title: ", web.title)
print("text: ", web.text)
# Out:
# Title:  Duży model językowy – Wikipedia, wolna encyklopedia
# text:  Przejdź do zawartości
# Menu główne
# Menu główne
# przypnij
# ukryj
# Nawigacja
# Strona główna
# Losuj artykuł
# Kategorie artykułów
# Najlepsze artykuły
# Częste pytania (FAQ)
# Dla czytelników
# O Wikipedii
# Kontakt
# Dla wikipedystów
# Pierwsze kroki
# Portal wikipedystów
# Ogłoszenia
# Zasady
# Pomoc
# Strony specjalne
# Ostatnie zmiany
# Szukaj
# Szukaj
# Wygląd
# Wspomóż Wikipedię
# Utwórz konto
# Zaloguj się
# Narzędzia osobiste
# Wspomóż Wikipedię
# Utwórz konto
# Zaloguj się
# Spis treści
# przypnij
# ukryj
# Początek
# 1
# Historia
# 2
# Trenowanie i architektura
# Przełącz podsekcję Trenowanie i architektura
# 2.1
# Wzmacnianie z informacją zwrotną od człowieka
# 2.2
# Mieszanka ekspertów
# 2.3
# Dostrajanie na podstawie instrukcji
# 3
# Koszt
# 4
# Rozumowanie
# 5
# Oddziaływanie
# Przełącz podsekcję Oddziaływanie
# 5.1
# Prawa autorskie
# 5.2
# Bezpieczeństwo
# 5.3
# Stronniczość algorytmiczna
# 5.4
# Zdrowie psychiczne
# 6
# Zobacz też
# 7
# Przypisy
# 8
# Linki zewnętrzne
# Przełącz stan spisu treści
# Duży model językowy
# 65 języków
# Afrikaans
# Aragonés
# العربية
# Azərbaycanca
# Boarisch
# Беларуская
# বাংলা
# Bosanski
# Català
# کوردی
# Čeština
# Dansk
# Deutsch
# Ελληνικά
# English
# Esperanto
# Español
# Eesti
# Euskara
# فارسی
# Suomi
# Français
# Gaeilge
# Galego
# עברית
# हिन्दी
# Magyar
# Հայերեն
# Bahasa Indonesia
# Ido
# Italiano
# 日本語
# La .lojban.
# Qaraqalpaqsha
# Қазақша
# 한국어
# Македонски
# Монгол
# नेपाल भाषा
# Nederlands
# Norsk nynorsk
# Norsk bokmål
# Português
# Runa Simi
# Română
# Русский
# Simple English
# Slovenščina
# Shqip
# Српски / srpski
# தமிழ்
# తెలుగు
# ไทย
# Tagalog
# Türkçe
# ئۇيغۇرچە / Uyghurche
# Українська
# اردو
# Oʻzbekcha / ўзбекча
# Tiếng Việt
# 文言
# 閩南語 / Bân-lâm-gí
# 粵語
# 中文
# IsiZulu
# Edytuj linki
# Artykuł
# Dyskusja
# polski
# Czytaj
# Edytuj
# Edytuj kod źródłowy
# Wyświetl historię
# Narzędzia
# Narzędzia
# przypnij
# ukryj
# Działania
# Czytaj
# Edytuj
# Edytuj kod źródłowy
# Wyświetl historię
# Ogólne
# Linkujące
# Zmiany w linkowanych
# Prześlij plik
# Link do tej wersji
# Informacje o tej stronie
# Cytowanie tego artykułu
# Zobacz skrócony adres URL
# Drukuj lub eksportuj
# Utwórz książkę
# Pobierz jako PDF
# Wersja do druku
# W innych projektach
# Wikimedia Commons
# Element Wikidanych
# Wygląd
# przypnij
# ukryj
# Z Wikipedii, wolnej encyklopedii
# Duży model językowy
# (ang.
# large language model
# ,
# LLM
# )
# [
# 1
# ]
# –
# model językowy
# wyszkolony na dużej ilości danych umożliwiający generowanie tekstu oraz realizację zadań związanych z
# przetwarzaniem języka naturalnego
# . Modele
# LLM
# są szkolone w ramach
# samonadzorowanego
# lub słabo nadzorowanego
# uczenia maszynowego
# z wykorzystaniem dużych ilości danych tekstowych. Proces ten jest intensywny obliczeniowo
# [
# 2
# ]
# . Duże modele językowe mogą być wykorzystywane do generowania tekstu poprzez wielokrotne przewidywanie następnego tokenu lub słowa, przez co zaliczane są do
# generatywnej sztucznej inteligencji
# [
# 3
# ]
# .
# Duże modele językowe są
# sieciami neuronowymi
# . Największe i najbardziej zdolne modele językowe oparte są na architekturze
# transformerów
# .
# Przykładami dużych modeli językowych są modele z serii
# GPT
# zbudowane przez
# OpenAI
# (np.
# GPT-3.5
# ﻿
# (inne języki)
# ,
# GPT-4
# ﻿
# (inne języki)
# ), używane w chatbotach
# ChataGPT
# i
# Microsoft Copilot
# , a także modele
# Llama
# zbudowane przez
# Meta Platforms
# . Istnieją również chińskie modele jak
# DeepSeek
# czy polskie jak
# Bielik
# i
# PLLuM
# .
# Historia
# [
# edytuj
# |
# edytuj kod
# ]
# Przed rokiem 2017 istniało kilka modeli językowych, które — jak na ówczesne możliwości — były uważane za duże. W latach 90.
# modele IBM
# pozwoliły na rozwinięcie się metod statystycznego modelowania języka. W 2001 roku model bazujący na
# n
# -gramach
# został wytrenowany na 300 milionach słów
# [
# 4
# ]
# . W latach dwutysięcznych, wraz z popularyzacją
# Internetu
# , rozpoczęto tworzenie zbiorów językowych o skali porównywalnej z Internetem
# [
# 5
# ]
# , na bazie których podjęto próby uczenia statystycznych modeli językowych
# [
# 6
# ]
# [
# 7
# ]
# .
# Po tym, jak sieci neuronowe stały się popularne w przetwarzaniu obrazów około 2012 roku
# [
# 8
# ]
# , zaczęto je również stosować do przetwarzania tekstu. W 2016 roku Google wprowadziło w
# Tłumaczu Google
# swój model językowy oparty na
# głębokiej sieci LSTM
# .
# Wykres pokazujący łączną ilość obliczeń (we
# FLOP
# -sach) wymaganą do wytrenowania modelu w kolejnych latach dla wybranych dużych modeli AI. Większość dużych modeli to modele językowe lub mutlimodalne ze zdolnościami przetwarzania języka.
# W 2017 roku naukowcy z Google zaproponowali architekturę
# transformera
# [
# 9
# ]
# opartą na
# mechanizmie uwagi
# opracowanym w 2014 roku
# [
# 10
# ]
# . W 2018 roku Google wypuściło model BERT oparty wyłącznie na
# koderach transformera
# [
# 11
# ]
# [
# 12
# ]
# . Od 2023 roku akademickie i badawcze zainteresowanie BERT-em zaczęło stopniowo maleć na rzecz modeli opartych na
# dekoderach transformera
# jak
# GPT
# [
# 13
# ]
# .
# Od 2022 roku zyskują na popularności modele o otwartym
# kodzie źródłowym
# – początkowo za sprawą projektów takich jak BLOOM
# [
# 14
# ]
# i
# Llama
# , choć oba objęte są ograniczeniami dotyczącymi zakresu zastosowań. Modele
# Mistral AI
# udostępnione zostały na bardziej liberalnej licencji
# Apache
# .
# Od 2023 roku wiele modeli ma charakter
# multimodalny
# , co oznacza, że potrafią analizować i generować różne typy danych, takie jak tekst, obrazy czy dźwięk
# [
# 15
# ]
# .
# W 2024 roku OpenAI wydało
# model rozumujący
# OpenAI o1, który generował długie
# łańcuchy myśli
# przed zwróceniem ostatecznej odpowiedzi
# [
# 16
# ]
# . W styczniu 2025 roku firma
# DeepSeek
# wypuściła w formie otwartego kodu model DeepSeek R1, mający 671 miliardów parametrów. Jego wydajność jest porównywalna z modelem OpenAI o1, przy znacznie niższych kosztach eksploatacji
# [
# 17
# ]
# .
# W roku 2024 największe i najbardziej zaawansowane modele językowe oparte są na architekturze transformera. Niektóre nowsze implementacje wykorzystują jednak inne podejścia, takie jak
# rekurencyjne sieci neuronowe
# (RNN) czy
# architektura Mamba
# ﻿
# (inne języki)
# [
# 18
# ]
# .
# Trenowanie i architektura
# [
# edytuj
# |
# edytuj kod
# ]
# Zobacz też:
# Dostrajanie (sztuczna inteligencja)
# .
# Wzmacnianie z informacją zwrotną od człowieka
# [
# edytuj
# |
# edytuj kod
# ]
# Uczenie się przez wzmacnianie z informacją zwrotną od człowieka (RLHF)
# to metoda umożliwiająca dostosowanie działania modelu językowego do ludzkich oczekiwań. Preferencje użytkowników definiuje się poprzez trenowanie tzw. modelu nagród, który następnie służy do dalszego uczenia modelu językowego z wykorzystaniem algorytmów
# uczenia przez wzmacnianie
# takich jak
# proximal policy optimization
# (PPO)
# [
# 19
# ]
# .
# Mieszanka ekspertów
# [
# edytuj
# |
# edytuj kod
# ]
# Zobacz też:
# Mieszanka ekspertów
# .
# Największe modele językowe bywają zbyt kosztowne w trenowaniu i bezpośrednim zastosowaniu. Dlatego coraz częściej stosuje się podejście mieszanki ekspertów (ang. Mixture of Experts, MoE)
# [
# 20
# ]
# [
# 21
# ]
# [
# 22
# ]
# . MoE to technika, która dzieli przestrzeń problemu między wiele wyspecjalizowanych
# sieci
# przez co
# inferencja
# aktywuje tylko te części sieci, które są najbardziej odpowiednie
# [
# 23
# ]
# , a sama metoda jest zaliczana do metod
# uczenia zespołowego
# [
# 24
# ]
# .
# Dostrajanie na podstawie instrukcji
# [
# edytuj
# |
# edytuj kod
# ]
# Duże modele językowe uczą się generować poprawne odpowiedzi i zastępować naiwne uzupełnienia dzięki kilku wstępnym korektom wprowadzonym przez człowieka oraz zastosowaniu podejścia
# self‑instruct
# . Na przykład w odpowiedzi na polecenie: „
# Napisz esej na temat głównych motywów przedstawionych w Hamlecie
# ” model mógłby najpierw wygenerować: „
# Jeśli oddasz esej po 17 marca, Twoja ocena zostanie obniżona o 10% za każdy dzień opóźnienia
# ”, bazując na częstotliwości takiego ciągu w
# korpusie
# [
# 25
# ]
# .
# Koszt
# [
# edytuj
# |
# edytuj kod
# ]
# Szacunkowy koszt trenowania wybranych modeli AI
# Trenowanie i działanie dużych modeli językowych zazwyczaj wymaga ogromnej
# mocy obliczeniowej
# i zużycia
# energii
# , co rodzi pytania dotyczące wpływu na
# środowisko
# [
# 26
# ]
# [
# 27
# ]
# .
# Rozumowanie
# [
# edytuj
# |
# edytuj kod
# ]
# Główny artykuł:
# model rozumujący
# .
# Pod koniec 2024 roku w rozwoju dużych modeli językowych pojawił się nowy kierunek, skoncentrowany na zadaniach wymagających złożonego
# rozumowania
# . Modele tego typu, określane jako „modele rozumujące”, zostały wytrenowane tak, aby poświęcać więcej czasu na generowanie rozwiązań krok po kroku (ang. chain-of-thought) przed udzieleniem odpowiedzi końcowej – w sposób zbliżony do ludzkiego procesu rozwiązywania problemów
# [
# 28
# ]
# . Trend ten zapoczątkowała firma OpenAI, wprowadzając we wrześniu 2024 roku model o1
# [
# 28
# ]
# , a następnie model o3 w grudniu 2024
# [
# 29
# ]
# . W porównaniu z tradycyjnymi LLM-ami, nowe modele wykazywały znaczną poprawę wyników w zadaniach z matematyki,
# nauk ścisłych
# oraz programowania. Przykładowo, na zadaniach z eliminacji do
# Międzynarodowej Olimpiady Matematycznej
# model GPT-4o uzyskał 13% skuteczności, podczas gdy model o1 osiągnął aż 83%
# [
# 29
# ]
# .
# W styczniu 2025 roku chińska firma
# DeepSeek
# przedstawiła model DeepSeek‑R1 — model rozumowania o otwartych wagach, posiadający 671 miliardów parametrów, który osiągnął wyniki porównywalne do modelu o1 firmy OpenAI, przy znacznie niższych kosztach operacyjnych. W przeciwieństwie do zastrzeżonych modeli OpenAI, otwarta architektura DeepSeek‑R1 umożliwiła badaczom analizę i dalszy rozwój algorytmu, choć dane treningowe pozostały nieupublicznione
# [
# 30
# ]
# .
# Modele rozumujące z reguły mają większe wymagania obliczeniowe w porównaniu z tradycyjnymi modelami LLM. Wynika to z tego, że model tego typu musi generować wiele odpowiedzi dla każdego kroku. Z drugiej strony modele tego typu pozwalają na osiągnięcie lepszych wyników w dziedzinach wymagających myślenia domenowego, np. w matematyce, badaniach naukowych czy programowaniu komputerowym
# [
# 29
# ]
# . Aby zmniejszyć ilość występowania
# halucynacji
# , stosowane są dodatkowe techniki jak
# automatyczne rozumowanie
# ,
# RAG
# czy
# dostrajanie
# [
# 31
# ]
# .
# Oddziaływanie
# [
# edytuj
# |
# edytuj kod
# ]
# Istnieją opinie twierdzące, że nie ma możliwości rozróżnienia tekstu stworzonego przez duży model językowy i przez człowieka
# [
# 32
# ]
# .
# Goldman Sachs
# w 2023 roku twierdził, że LLM-y są w stanie zwiększyć globalne
# PKB
# o 7% w ciągu dekady i bedą potrafiły wystawić na automatyzację pracę 300 mln osób
# [
# 33
# ]
# [
# 34
# ]
# .
# Prawa autorskie
# [
# edytuj
# |
# edytuj kod
# ]
# W roku 2023, do sądów w
# Stanach Zjednoczonych
# wpłynęło kilka wniosków podważających używanie danych chronionych
# prawem autorskim
# do trenowania modeli językowych z obrońcami opierającymi się na instytucji
# fair use
# [
# 35
# ]
# .
# Bezpieczeństwo
# [
# edytuj
# |
# edytuj kod
# ]
# Duże modele językowe mogą być używane do tworzenia
# dezinformacji
# , w sposób świadomy lub nie lub do innych celów
# [
# 36
# ]
# . Dostępność dużych modeli językowych może pozwolić na obniżenie poziom umiejętności wymaganych do popełnienia czynów
# bioterroryzmu
# [
# 37
# ]
# .
# Dodatkowo, istnieje możliwość osadzenia uśpionych
# inteligentnych agentów
# , czyli ukrytych funkcjonalności, które w normalnych warunkach nie wykonują akcji, a po uzyskaniu impulsu aktywującego, rozpoczynają wykonywania szkodliwych działań
# [
# 38
# ]
# .
# Aplikacje LLM zawierają odpowiednie filtry moderacyjne jednak nie są one w pełni efektywne i pozwalają na wykorzystanie jako
# technologia podwójnego zastosowania
# [
# 39
# ]
# czy różnych nielegalnych operacji
# [
# 40
# ]
# .
# Stronniczość algorytmiczna
# [
# edytuj
# |
# edytuj kod
# ]
# Podczas gdy duże modele językowe są w stanie generować tekst przypominający ludzki, są skłonne do dziedziczenia i powiększania stronniczości zawartej w
# danych testowych
# . Stronniczość może się objawiać w błędnym i niesprawiedliwym traktowaniu różnych grup demograficznych
# [
# 41
# ]
# .
# Zdrowie psychiczne
# [
# edytuj
# |
# edytuj kod
# ]
# Badania oraz wpisy w mediach społecznościowych sugerują, że część osób korzysta z LLM-ów w poszukiwaniu terapii lub wsparcia psychologicznego
# [
# 42
# ]
# . Z badania przeprowadzonego na Sentio University w 2025 r. wynika, że niemal połowa (48,7%) spośród 499 dorosłych Amerykanów z utrzymującymi się problemami psychicznymi, którzy korzystali z dużych modeli językowych, deklarowała zwracanie się do nich po terapię lub wsparcie emocjonalne, m.in. w radzeniu sobie z lękiem, depresją czy samotnością
# [
# 43
# ]
# . Jednocześnie badania pokazują, że halucynacje modeli językowych – czyli wypowiedzi brzmiące wiarygodnie, lecz nieprawdziwe – we wrażliwych kontekstach związanych ze zdrowiem psychicznym mogą wprowadzać użytkowników w błąd
# [
# 44
# ]
# . Z badań wynika również, że LLM potrafią przejawiać stygmatyzujące postawy lub w nieodpowiedni sposób potwierdzać dezadaptacyjne myśli, co podkreśla ograniczenia tych systemów w zakresie osądu i kompetencji relacyjnych
# [
# 45
# ]
# . Oceny scenariuszy kryzysowych ujawniają ponadto, że w modelach może brakować skutecznych mechanizmów bezpieczeństwa, takich jak ocena ryzyka samobójstwa czy kierowanie użytkowników do odpowiednich form pomocy
# [
# 46
# ]
# [
# 47
# ]
# .
# W tym kontekście, w 2025 roku podkreślano o 50% wyższy poziom sykofancji niż w przypadku ludzi, czyli skłonności dużych modeli językowych do przytakiwania użytkownikowi i potwierdzania jego opinii, nawet jeśli są one błędne, niebezpieczne lub irracjonalne
# [
# 48
# ]
# . W obszarze
# zdrowia psychicznego
# , LLMy mogą powodować
# psychozę
# u osób podatnych
# [
# 49
# ]
# . Problem był szczególnie widoczny w modelu GPT 4o, co zostało szybko poprawione
# [
# 50
# ]
# i również naprawione w modelu GPT-5, gdzie liczba udzielania nadmierne pochlebnych lub ugodowych odpowiedzi spadła z 14,5% w poprzedniej wersji do mniej niż 6%
# [
# 51
# ]
# .
# Zobacz też
# [
# edytuj
# |
# edytuj kod
# ]
# benchmark modelu językowego
# mały model językowy
# model fundamentalny
# model rozumujący
# osadzanie słów
# postęp w sztucznej inteligencji
# Przypisy
# [
# edytuj
# |
# edytuj kod
# ]
# ↑
# A short history of AI
# . „
# The Economist
# ”, s. 56, 20th July 2024.
# ↑
# OpenAI
# :
# Better language models and their implications
# . [dostęp 2024-05-08]. [zarchiwizowane z
# tego adresu
# (2020-12-19)].
# ↑
# Czym jest generatywna sztuczna inteligencja? | Deloitte
# [online], Deloitte Polska
# [dostęp 2024-05-08]
# (
# pol.
# )
# .
# ↑
# Joshua
# J.
# Goodman
# Joshua
# J.
# ,
# A Bit of Progress in Language Modeling
# , „arXiv”,
# 2001
# ,
# DOI
# :
# 10.48550/arXiv.cs/0108005
# ,
# arXiv
# :
# cs/0108005
# [dostęp 2025-04-11]
# .
# ↑
# Adam
# A.
# Kilgarriff
# Adam
# A.
# ,
# Gregory
# G.
# Grefenstette
# Gregory
# G.
# ,
# Introduction to the Special Issue on the Web as Corpus
# , „Computational Linguistics”, 29 (3),
# 2003
# , s. 333–347,
# DOI
# :
# 10.1162/089120103322711569
# ,
# ISSN
# 0891-2017
# [dostęp 2025-04-11]
# .
# ↑
# Michele
# M.
# Banko
# Michele
# M.
# ,
# Eric
# E.
# Brill
# Eric
# E.
# ,
# Scaling to very very large corpora for natural language disambiguation
# , „Proceedings of the 39th Annual Meeting on Association for Computational Linguistics”, ACL '01, USA: Association for Computational Linguistics,
# 2001
# , s. 26–33,
# DOI
# :
# 10.3115/1073012.1073017
# [dostęp 2025-04-11]
# .
# ↑
# Philip
# P.
# Resnik
# Philip
# P.
# ,
# Noah A.
# N.A.
# Smith
# Noah A.
# N.A.
# ,
# The Web as a Parallel Corpus
# , „Computational Linguistics”, 29 (3),
# 2003
# , s. 349–380,
# DOI
# :
# 10.1162/089120103322711578
# ,
# ISSN
# 0891-2017
# [dostęp 2025-04-11]
# .
# ↑
# Chen
# i inni
# ,
# Review of Image Classification Algorithms Based on Convolutional Neural Networks
# , „Remote Sensing”, 13 (22),
# 2021
# ,
# DOI
# :
# 10.3390/r
# ,
# ISSN
# 2072-4292
# [dostęp 2025-04-11]
# [zarchiwizowane z
# adresu
# 2025-03-07]
# (
# ang.
# )
# .
# ↑
# Vaswani
# i inni
# ,
# Attention is All you Need
# [online], Advances in Neural Information Processing Systems. 30. Curran Associates, Inc, 2017
# (
# ang.
# )
# .
# ↑
# Dzmitry
# D.
# Bahdanau
# Dzmitry
# D.
# ,
# Kyunghyun
# K.
# Cho
# Kyunghyun
# K.
# ,
# Yoshua
# Y.
# Bengio
# Yoshua
# Y.
# ,
# Neural Machine Translation by Jointly Learning to Align and Translate
# , „arXiv”,
# 2016
# ,
# DOI
# :
# 10.48550/arXiv.1409.0473
# ,
# arXiv
# :
# 1409.0473
# [dostęp 2025-04-11]
# .
# ↑
# Jacob
# J.
# Devlin
# Jacob
# J.
# ,
# Ming-Wei
# M.W.
# Chang
# Ming-Wei
# M.W.
# ,
# Kenton
# K.
# Lee
# Kenton
# K.
# ,
# Kristina
# K.
# Toutanova
# Kristina
# K.
# ,
# BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding
# , „arXiv”,
# 2019
# ,
# DOI
# :
# 10.48550/arXiv.1810.04805
# ,
# arXiv
# :
# 1810.04805v2
# [dostęp 2025-04-15]
# .
# ↑
# Open Sourcing BERT: State-of-the-Art Pre-training for Natural Language Processin
# [online], research.google
# [dostęp 2025-04-15]
# (
# ang.
# )
# .
# ↑
# Rajiv
# R.
# Movva
# Rajiv
# R.
# i inni
# ,
# Topics, Authors, and Institutions in Large Language Model Research: Trends from 17K arXiv Papers
# , „arXiv”,
# 2024
# ,
# DOI
# :
# 10.48550/arXiv.2307.10700
# ,
# arXiv
# :
# 2307.10700
# [dostęp 2025-04-11]
# .
# ↑
# bigscience/bloom · Hugging Face
# [online], huggingface.co
# [dostęp 2025-04-11]
# .
# ↑
# Dr Tehseen
# D.T.
# Zia
# Dr Tehseen
# D.T.
# ,
# Unveiling of Large Multimodal Models: Shaping the Landscape of Language Models in 2024
# [online], Unite.AI, 8 stycznia 2024
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Cade
# C.
# Metz
# Cade
# C.
# ,
# OpenAI Unveils New ChatGPT That Can Reason Through Math and Science
# , „
# The New York Times
# ”, 12 września 2024
# ,
# ISSN
# 0362-4331
# [dostęp 2025-07-16]
# (
# ang.
# )
# .
# ↑
# Shubham
# S.
# Sharma
# Shubham
# S.
# ,
# Open-source DeepSeek-R1 uses pure reinforcement learning to match OpenAI o1 — at 95% less cost
# [online], VentureBeat, 20 stycznia 2025
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Dr Tehseen
# D.T.
# Zia
# Dr Tehseen
# D.T.
# ,
# Unveiling of Large Multimodal Models: Shaping the Landscape of Language Models in 2024
# [online], Unite.AI, 8 stycznia 2024
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Long
# L.
# Ouyang
# Long
# L.
# i inni
# ,
# Training language models to follow instructions with human feedback
# , „arXiv”,
# 2022
# ,
# DOI
# :
# 10.48550/arXiv.2203.02155
# ,
# arXiv
# :
# 2203.02155
# [dostęp 2025-04-11]
# .
# ↑
# Noam
# N.
# Shazeer
# Noam
# N.
# i inni
# ,
# Outrageously Large Neural Networks: The Sparsely-Gated Mixture-of-Experts Layer
# , „arXiv”,
# 2017
# ,
# DOI
# :
# 10.48550/arXiv.1701.06538
# ,
# arXiv
# :
# 1701.06538
# [dostęp 2025-04-11]
# .
# ↑
# Dmitry
# D.
# Lepikhin
# Dmitry
# D.
# i inni
# ,
# GShard: Scaling Giant Models with Conditional Computation and Automatic Sharding
# , „arXiv”,
# 2020
# ,
# DOI
# :
# 10.48550/arXiv.2006.16668
# ,
# arXiv
# :
# 2006.16668
# [dostęp 2025-04-11]
# .
# ↑
# More Efficient In-Context Learning with GLaM
# [online], research.google
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Tara
# T.
# Baldacchino
# Tara
# T.
# ,
# Elizabeth J.
# E.J.
# Cross
# Elizabeth J.
# E.J.
# ,
# Keith
# K.
# Worden
# Keith
# K.
# ,
# Jennifer
# J.
# Rowson
# Jennifer
# J.
# ,
# Variational Bayesian mixture of experts models and sensitivity analysis for nonlinear dynamical systems
# , „Mechanical Systems and Signal Processing”, 66,
# 2016
# , s. 178–200,
# DOI
# :
# 10.1016/j.ymssp.2015.05.009
# ,
# ISSN
# 0888-3270
# ,
# Bibcode
# :
# 2016MSSP...66..178B/abstract
# [dostęp 2025-04-11]
# .
# ↑
# Pattern Classification Using Ensemble Methods | Series in Machine Perception and Artificial Intelligence
# , www.worldscientific.com,
# DOI
# :
# 10.1142/7238#t=aboutbook
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Yizhong
# Y.
# Wang
# Yizhong
# Y.
# i inni
# ,
# Self-Instruct: Aligning Language Models with Self-Generated Instructions
# , „arXiv”,
# 2023
# ,
# DOI
# :
# 10.48550/arXiv.2212.10560
# ,
# arXiv
# :
# 2212.10560
# [dostęp 2025-04-11]
# .
# ↑
# Large Language Model (LLM)? - FEB
# [online], feb.net.pl
# [dostęp 2025-02-13]
# .
# ↑
# Anna
# A.
# Klee-Bylica
# Anna
# A.
# ,
# Czy wiesz, jak dużo energii potrzebuje sztuczna inteligencja?
# [online], Zielony blog WSIiZ, 16 maja 2024
# [dostęp 2025-02-13]
# .
# ↑
# a
# b
# Introducing OpenAI o1
# [online], openai.com
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# a
# b
# c
# Cade
# C.
# Metz
# Cade
# C.
# ,
# OpenAI Unveils New A.I. That Can ‘Reason’ Through Math and Science Problems
# , „
# The New York Times
# ”, 20 grudnia 2024
# ,
# ISSN
# 0362-4331
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Elizabeth
# E.
# Gibney
# Elizabeth
# E.
# ,
# China’s cheap, open AI model DeepSeek thrills scientists
# , „
# Nature
# ”, 638 (8049),
# 2025
# , s. 13–14,
# DOI
# :
# 10.1038/d41586-025-00229-6
# ,
# ISSN
# 1476-4687
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Belle
# B.
# Lin
# Belle
# B.
# ,
# Why Amazon is Betting on ‘Automated Reasoning’ to Reduce AI’s Hallucinations
# , „Wall Street Journal”, 5 lutego 2025
# ,
# ISSN
# 0099-9660
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Prepare for truly useful large language models
# , „Nature Biomedical Engineering”, 7 (2),
# 2023
# , s. 85–86,
# DOI
# :
# 10.1038/s41551-023-01012-6
# ,
# ISSN
# 2157-846X
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Your job is (probably) safe from artificial intelligence
# , „
# The Economist
# ”
# ,
# ISSN
# 0013-0613
# [dostęp 2025-04-11]
# .
# ↑
# Generative AI could raise global GDP by 7%
# [online], www.goldmansachs.com
# (
# ang.
# )
# .
# ↑
# Artificial Intelligence Copyright Challenges in US Courts Surge
# [online], natlawreview.com
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Davey
# D.
# Alba
# Davey
# D.
# ,
# AI chatbots have been used to create dozens of news content farms
# [online], The Japan Times, 1 maja 2023
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Could chatbots help devise the next pandemic virus?
# [online], www.science.org
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Evan
# E.
# Hubinger
# Evan
# E.
# i inni
# ,
# Sleeper Agents: Training Deceptive LLMs that Persist Through Safety Training
# , „arXiv”,
# 2024
# ,
# DOI
# :
# 10.48550/arXiv.2401.05566
# ,
# arXiv
# :
# 2401.05566
# [dostęp 2025-04-11]
# .
# ↑
# Daniel
# D.
# Kang
# Daniel
# D.
# i inni
# ,
# Exploiting Programmatic Behavior of LLMs: Dual-Use Through Standard Security Attacks
# , „arXiv”,
# 2023
# ,
# DOI
# :
# 10.48550/arXiv.2302.05733
# ,
# arXiv
# :
# 2302.05733
# [dostęp 2025-04-11]
# .
# ↑
# Encryption Based Covert Channel for Large Language Models
# [online], IACR ePrint 2024/586, 2024
# .
# ↑
# Chris
# Ch.
# Stokel-Walker
# Chris
# Ch.
# ,
# ChatGPT Replicates Gender Bias in Recommendation Letters
# [online], Scientific American
# [dostęp 2025-04-11]
# (
# ang.
# )
# .
# ↑
# Innkommet litteratur
# , „Heimen”, 54 (4),
# 2017
# , s. 365–368,
# DOI
# :
# 10.18261/issn.1894-3195-2017-04-10
# ,
# ISSN
# 0017-9841
# [dostęp 2025-08-19]
# .
# ↑
# Tony
# T.
# Rousmaniere
# Tony
# T.
# ,
# Yimeng
# Y.
# Zhang
# Yimeng
# Y.
# ,
# Xu
# X.
# Li
# Xu
# X.
# ,
# Siddharth
# S.
# Shah
# Siddharth
# S.
# ,
# Large language models as mental health resources: Patterns of use in the United States.
# , „Practice Innovations”,
# 2025
# ,
# DOI
# :
# 10.1037/pri0000292
# ,
# ISSN
# 2377-8903
# [dostęp 2025-08-19]
# (
# ang.
# )
# .
# ↑
# Shaoxiong
# S.
# Ji
# Shaoxiong
# S.
# ,
# Tianlin
# T.
# Zhang
# Tianlin
# T.
# ,
# Kailai
# K.
# Yang
# Kailai
# K.
# ,
# Sophia
# S.
# Ananiadou
# Sophia
# S.
# ,
# Erik
# E.
# Cambria
# Erik
# E.
# ,
# Rethinking Large Language Models in Mental Health Applications
# , „arXiv”,
# 2023
# ,
# DOI
# :
# 10.48550/arXiv.2311.11267
# ,
# arXiv
# :
# 2311.11267
# [dostęp 2025-08-19]
# (
# ang.
# )
# .
# ↑
# Jared
# J.
# Moore
# Jared
# J.
# i inni
# ,
# Expressing stigma and inappropriate responses prevents LLMs from safely replacing mental health providers.
# , ACM, 23 czerwca 2025, s. 599–627,
# DOI
# :
# 10.1145/3715275.3732039
# ,
# ISBN
# 979-8-4007-1482-5
# [dostęp 2025-08-19]
# (
# ang.
# )
# .
# ↑
# Declan
# D.
# Grabb
# Declan
# D.
# ,
# Max
# M.
# Lamparth
# Max
# M.
# ,
# Nina
# N.
# Vasan
# Nina
# N.
# ,
# Risks from Language Models for Automated Mental Healthcare: Ethics and Structure for Implementation
# , „arXiv”,
# 2024
# ,
# DOI
# :
# 10.48550/arXiv.2406.11852
# ,
# arXiv
# :
# 2406.11852
# [dostęp 2025-08-19]
# .
# ↑
# Ryan K
# R.K.
# McBain
# Ryan K
# R.K.
# i inni
# ,
# Competency of Large Language Models in Evaluating Appropriate Responses to Suicidal Ideation: Comparative Study
# , „Journal of Medical Internet Research”, 27,
# 2025
# , e67891,
# DOI
# :
# 10.2196/67891
# ,
# ISSN
# 1438-8871
# ,
# PMID
# :
# 40053817
# ,
# PMCID
# :
# PMC11928068
# [dostęp 2025-08-19]
# (
# ang.
# )
# .
# ↑
# Miryam
# M.
# Naddaf
# Miryam
# M.
# ,
# AI chatbots are sycophants — researchers say it’s harming science
# , „
# Nature
# ”, 647 (8088),
# 2025
# , s. 13–14,
# DOI
# :
# 10.1038/d41586-025-03390-0
# ,
# ISSN
# 1476-4687
# [dostęp 2026-02-06]
# (
# ang.
# )
# .
# ↑
# Arianna
# A.
# Huffington
# Arianna
# A.
# ,
# The Problem With AI Flattering Us
# , „TIME”
# [dostęp 2026-02-06]
# [zarchiwizowane z
# adresu
# 2026-01-17]
# (
# ang.
# )
# .
# ↑
# Sycophancy in GPT-4o: What happened and what we’re doing about it
# [online], openai.com
# [dostęp 2026-02-06]
# (
# ang.
# )
# .
# ↑
# Przedstawiamy model GPT-5
# [online], openai.com, 3 lutego 2026
# [dostęp 2026-02-05]
# .
# Linki zewnętrzne
# [
# edytuj
# |
# edytuj kod
# ]
# Large Language Models explained briefly
# . 3Blue1Brown  2024-11-20.    [dostęp 2025-02-16].
# p
# d
# e
# Sztuczna inteligencja
# Główne cechy
# automatyczne planowanie
# bezpieczeństwo
# integracja systemów
# ﻿
# (inne języki)
# inteligentny agent
# przetwarzanie języka naturalnego
# robotyka
# rozpoznawanie obrazów
# rozumowanie oparte na wiedzy
# ogólna sztuczna inteligencja
# samodoskonalenie
# Filozofia
# chiński pokój
# etyka
# paradoks Moraveca
# sztuczna świadomość
# test Turinga
# Pojęcia
# benchmark
# dolina niesamowitości
# funkcja aktywacji
# funkcja softmax
# funkcja sigmoidalna
# funkcja ReLU
# halucynacja
# klasteryzacja
# inżynieria podpowiedzi
# mechanizm uwagi
# metoda gradientu prostego
# metoda gradientu sprzężonego
# autoregresja
# osadzanie słów
# parametr
# hiperparametr
# propagacja wsteczna
# obciążenie
# regresja
# kompromis między obciążeniem a wariancją
# podwójny spadek
# nadmierne dopasowanie
# RAG
# regularyzacja
# RLHF
# splot
# uczenie antagonistyczne
# uczenie przez wzmacnianie
# zbiór danych
# Zastosowania
# agent AI
# Model Context Protocol
# model językowy
# duży model językowy
# model rozumujący
# sieć neuronowa
# uczenie głębokie
# uczenie maszynowe
# Implementacje
# Audio-wizualne
# rozpoznawanie pisma ręcznego
# OCR
# synteza mowy
# 15.ai
# ElevenLabs
# rozpoznawanie mowy
# rozpoznawanie twarzy
# ﻿
# (inne języki)
# tekst-do-obrazu
# DALL-E
# Stable Diffusion
# Midjourney
# tekst-do-wideo
# Kuaishou
# Sora
# Veo
# Tekstowe
# Bielik
# Claude
# Copilot
# DeepSeek
# Gemma
# Gemini
# GPT
# ChatGPT
# Grok
# IBM Watson
# Llama
# Perplexity AI
# PLLuM
# Qwen
# Decyzyjne
# AlphaGo
# samochód autonomiczny
# wybór akcji
# AutoGPT
# Architektury
# autoenkoder
# autoenkoder wariacyjny
# konwolucyjna sieć neuronowa
# perceptron wielowarstwowy
# rekurencyjna sieć neuronowa
# długa pamięć krótkotrwała (LSTM)
# sieć generatywna GAN
# transformer
# transformer wizyjny
# p
# d
# e
# Generatywna sztuczna inteligencja
# Pojęcia
# autoenkoder
# dostrajanie
# duży model językowy
# efekt Waluigi
# inżynieria podpowiedzi
# mieszanka ekspertów
# Model Context Protocol
# model fundamentalny
# osadzanie słów
# papuga stochastyczna
# RAG
# RLHF
# sieć generatywna GAN
# transformer
# transformer wizyjny
# uczenie głębokie
# vibe coding
# Modele
# Tekst
# Bielik
# Claude
# DeepSeek
# ERNIE
# Gemma
# Gemini
# Grok
# GPT
# ChatGPT
# Llama
# Mistral
# PLLuM
# Qwen
# Mowa
# 15.ai
# ElevenLabs
# Obraz
# GPT Image 1
# Midjourney
# Qwen-Image
# Stable Diffusion
# Programowanie
# Claude Code
# Copilot
# Cursor
# ﻿
# (inne języki)
# Kimi
# Qwen3-Coder
# Wideo
# Sora
# Agent AI
# AutoGLM
# AutoGPT
# ChatGPT Deep Research
# Manus
# p
# d
# e
# Uczenie maszynowe
# i
# eksploracja danych
# Paradygmaty
# uczenie nadzorowane
# uczenie nienadzorowane
# uczenie przez wzmacnianie
# uczenie samonadzorowane
# Zagadnienia
# inferencja gramatyki
# inżynieria cech
# klasteryzacja
# klasyfikacja
# regresja
# redukcja wymiaru
# uczenie multimodalne
# uczenie (się) cech
# wykrywanie anomalii
# Uczenie nadzorowane
# (
# Klasyfikacja
# ,
# Regresja
# )
# drzewa klasyfikacyjne
# uczenie zespołowe
# agregacja
# las losowy
# k najbliższych sąsiadów
# regresja liniowa
# naiwny klasyfikator bayesowski
# sieć neuronowa
# regresja logistyczna
# perceptron
# maszyna wektorów nośnych
# Klasteryzacja
# grupowanie hierarchiczne
# algorytm centroidów
# DBSCAN
# inferencja gramatyki
# Redukcja wymiaru
# analiza czynnikowa
# korelacja kanoniczna
# liniowa analiza dyskryminacyjna
# analiza głównych składowych
# Sieć neuronowa
# autoenkoder
# uczenie głębokie
# jednokierunkowa sieć neuronowa
# model dyfuzyjny
# rekurencyjna sieć neuronowa
# LSTM
# sieć generatywna GAN
# sieć Kohonena
# konwolucyjna sieć neuronowa
# transformer
# Kontrola autorytatywna
# (
# model językowy
# ):
# GND
# :
# 1322631905
# BNCF
# :
# 77644
# NKC
# :
# ph1274563
# LNB
# :
# 000355290
# Encyklopedie internetowe
# :
# Britannica
# :
# topic/large-language-model
# Źródło: „
# https://pl.wikipedia.org/w/index.php?title=Duży_model_językowy&oldid=79556961
# ”
# Kategorie
# :
# Duże modele językowe
# Przetwarzanie języka naturalnego
# Ukryte kategorie:
# Szablon cytowania używa pól opisowych
# Szablon cytowania zamienił nazwę czasopisma
# Artykuły z propozycjami tłumaczeń
# Tę stronę ostatnio edytowano 15 kwi 2026, 22:23.
# Tekst udostępniany na licencji
# Creative Commons: uznanie autorstwa, na tych samych warunkach
# , z możliwością obowiązywania dodatkowych ograniczeń.
# Zobacz szczegółowe informacje o
# warunkach korzystania
# .
# Polityka prywatności
# O Wikipedii
# Korzystasz z Wikipedii tylko na własną odpowiedzialność
# Kontakty prawne i dotyczące bezpieczeństwa
# Powszechne Zasady Postępowania
# Dla deweloperów
# Statystyki
# Oświadczenie o ciasteczkach
# Wersja mobilna
# Szukaj
# Szukaj
# Przełącz stan spisu treści
# Duży model językowy
# 65 języków
# Dodaj temat

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown in Polish."

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "\nThe contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# Opcjonalnie - podgląd wiadomości
web = Website("https://wp.pl")
messages_for(web)
# Out:
# [{'role': 'system',
#   'content': 'You are an assistant that analyzes the contents of a website and provides a short summary, ignoring text that might be navigation related. Respond in markdown in Polish.'},
#  {'role': 'user',
#   'content': 'You are looking at a website titled Wirtualna Polska - Wszystko co ważne - www.wp.pl\nThe contents of this website is as follows; please provide a short summary of this website in markdown. If it includes news or announcements, then summarize these too.\n\nwp.pl\nSprawdź pogodę na 7 dni\nPremium\nWyniki\nPrzepisy\nQuizy\nTV Online\nRadio\nPoczta\nMenu\nZaloguj\nTurystyka\nTurystyka\nPlaże\nWyspy\nEgzotyka\nW podróży\nMiasta\nPoza miastem\nWideo\nREKLAMA\nParkingi przy lotnisku\nInformacje\nWiadomości\nNewsy\nWiadomości pogodowe\no2\nMateusz Morawiecki\nWybory Prezydenckie\nJanusz Korwin-Mikke\nHoroskop\nMariusz Błaszczak\nTomasz Grodzki\nMariusz Kamiński\nOlga Tokarczuk\nDonald Trump\nAndrzej Duda\nBiznes i Finanse\nMoney.pl\nWP Finanse\nGiełda\nKursy walut\nRejestr firm\nPrawo\nKalkulator walut\nPPK\nKalkulator wynagrodzeń\nEmerytury\nSesje ELIXIR\nPraca\nREKLAMA\nKredyty gotówkowe Totalmoney.pl\nREKLAMA\nKredyty gotówkowe Direct.Money.pl\nSport\nWP SportoweFakty\nŻużel\nŻużel - Ekstraliga\nPiłka nożna\nPiłka nożna - Ekstraklasa\nSiatkówka\nSkoki Narciarskie\nF1\nKoszykówka\nReprezentacja Polski w piłce nożnej\nMecze na żywo\nWyniki meczów\nIgrzyska Olimpijskie - Paryż 2024\nRozrywka i Styl\nDom\nFacet\nKuchnia\nKafeteria\nKobieta\nKsiążki\nFilm\nHoroskop\nVibez\nWP Radar Okazji\nDomodi\nRozrywka o2\nShow-biznes\nTeleshow\nPudelek\nGwiazdy\nCzerwony dywan\nTelewizja Jastrząb\nPRACA.MONEY.PL\nPraca\nOferty pracy\nPraca Warszawa\nPraca Kraków\nPraca Łódź\nPraca Wrocław\nPraca Poznań\nPraca Szczecin\nPraca Bydgoszcz\nPraca Katowice\nPraca Gdynia\nPraca Radom\nPraca za granicą\nPraca w miastach\nListy ofert pracy\nSzukane oferty\nPopularne stanowiska pracy\nWynagrodzenia\nTechnologie\nWP Tech\nKomórkomania\nFotoblogia\nGadżetomania\nWP Gry\nKatalog telefonów i tabletów\nKatalog aparatów fotograficznych i obiektywów\nCzyj to numer?\nDobreprogramy\nDarmowe programy do obróbki zdjęć\nLucky Patcher\nCcleaner\nWinRAR\nuTorrent\nDAEMON Tools Lite\nPolygamia\nBenchmark\nRanking kart graficznych\nRanking procesorów\nPorównywarka telefonów\nSpeedTest - test prędkości internetu\nLaptop gamingowy do 5000 złotych\nSamsung Galaxy S24 Ultra\nZdrowie i Dziecko\nCiąża i poród\nParenting\nRanking lekarzy\nRozwój dziecka\nZdrowie\nŻywienie\nFitness\nUroda\nAktywność fizyczna\nPsychologia\nLeki i suplementy\nSeks\nKalkulatory\nPierwsza pomoc\nBadania\nPytania do specjalistów\nZdrowie dziecka\nRelacje i związki\nMoto\nAutokult\nAutocentrum\nMoto\nDane techniczne\nSprawdź VIN\nKalkulator LPG\nKalkulator KW na KM\nWirtualny alkomat\nDziennik kosztów\nOgłoszenia motoryzacyjne\nTesty i opinie\nTesty zderzeniowe\nTesty samochodów\nSamochody używane\nSamochody elektryczne\nKuchnia\nPyszności Przepisy\nSałatka ziemniaczana\nCiasto z rabarbarem\nPlacki z cukinii\nCiasto z truskawkami\nBotwinka\nSurówka z czerwonej kapusty\nPlacki z serka wiejskiego\nGołąbki z młodej kapusty\nSos czosnkowy\nCiasto z wiśniami\nZapiekanka z cukinii\nCiasto Milky Way\nCynamonki z ciasta francuskiego\nPogoda\nPogoda\nPogoda w Polsce\nPogoda Zakopane\nPogoda Warszawa\nPogoda Gdańsk\nPogoda Łódź\nPogoda Lublin\nPogoda Wrocław\nPogoda Kraków\nPogoda Bydgoszcz\nPogoda Poznań\nPogoda Białystok\nPogoda Częstochowa\nPogoda Kielce\nPogoda Gdynia\nPogoda Radom\nMENU\nWP PREMIUM\nWiadomości\nSport\nWP SportoweFakty\nPiłka nożna\nŻużel\nSiatkówka\nSporty Walki\nPiłka ręczna\nKoszykówka\nTenis\nFormuła 1\nRobert Lewandowski\nIga Świątek\nPKO Ekstraklasa\nPogoda\nWP Pogoda\nWiadomości pogodowe\nPogoda Warszawa\nPogoda Zakopane\nPogoda Kraków\nPogoda Wrocław\nPogoda Lublin\nPogoda Poznań\nPogoda Gdańsk\nPogoda Łódź\nPogoda Białystok\nBiznes i finanse\nMoney.pl\nWP Finanse\nPraca\nGiełda\nWaluty\nZdrowie i dziecko\nABC Zdrowie\nParenting\nZdrowie\nCiąża\nSeks\nPsychologia\nZdrowie dziecka\nImiennik\nŻywienie\nUroda\nLeki i suplementy\nBadania\nShowbiznes\nPudelek\nJastrząbPost.pl\nGalerie\nWideo\nTelewizja Jastrząb\nMotoryzacja\nAutokult\nWP Moto\nTechnologia\nWP tech\nDobre Prog ...

# %%
MODEL = 'llama3.2'

def summarize(url):
    website = Website(url)
    response = ollama.chat(
        model=MODEL,
        messages=messages_for(website)
    )
    return response['message']['content']

# Test
summarize("https://wp.pl")
# Out:
# '"Świetli mi wiele rzeczy, a zawsze wylecamy was!"'

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# Ostatnia linia projektu
display_summary("https://wp.pl")
